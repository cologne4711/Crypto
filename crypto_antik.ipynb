# %% [markdown]
# # 🔐 Klassische Verschlüsselungsverfahren in Python
#
# In diesem Notebook implementierst du selbst:
# - Caesar-Verschlüsselung
# - Polybios-Quadrat
# - Monoalphabetische Substitution
#
# Ziel: Verständnis für Algorithmen + Python.

# %% [markdown]
# ## 🧰 Python-Grundlagen

# %%
print(ord("A"))
print(chr(65))

# %% [markdown]
# 👉 `ord()` → Buchstabe → Zahl
# 👉 `chr()` → Zahl → Buchstabe

# %%
print(5 % 3)
print(26 % 26)

# %% [markdown]
# 👉 `%` sorgt für Wrap-around

# %% [markdown]
# ## 🏛️ Caesar-Verschlüsselung

# %%
def shift_char(char, shift):
    # TODO
    pass

print(shift_char("A", 3))
print(shift_char("Z", 1))

# %%
def caesar_encrypt(text, shift):
    result = ""
    
    for char in text:
        if char.isalpha():
            # TODO
            pass
        else:
            result += char
            
    return result

print(caesar_encrypt("HALLO", 3))

# %%
def caesar_decrypt(text, shift):
    # TODO
    pass

# %% [markdown]
# ## 🏺 Polybios-Quadrat

# %%
alphabet = "ABCDEFGHIKLMNOPQRSTUVWXYZ"

def create_square():
    # TODO
    pass

# %%
def find_position(square, char):
    # TODO
    pass

# %%
def polybios_encrypt(text):
    square = create_square()
    result = ""
    
    for char in text:
        if char.isalpha():
            # TODO
            pass
    
    return result

# %% [markdown]
# ## 🔤 Monoalphabetische Substitution

# %%
mapping = {
    "A": "Q", "B": "W", "C": "E", "D": "R"
    # TODO
}

def substitute_encrypt(text, mapping):
    result = ""
    
    for char in text:
        if char.isalpha():
            # TODO
            pass
        else:
            result += char
    
    return result

# %%
def invert_mapping(mapping):
    inv = {}
    # TODO
    return inv

# %%
def substitute_decrypt(text, mapping):
    # TODO
    pass

# %% [markdown]
# ## 🎯 Bonus

# %%
secret = "KHOOR ZRUOG"
print("Kannst du das entschlüsseln?")
